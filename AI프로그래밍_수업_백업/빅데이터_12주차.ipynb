# %% [markdown]
# <a href="https://colab.research.google.com/github/leegaon0622/Bigdata/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0_12%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 과제1) 인천광역시 미추홀구_재래시장_20220822.csv 화일에 포함되어 있는
# 재래시장들의 위치를 marker에 표시 하시오.
#  지도의 중심 위치는 7호관뒤 수준 원점으로 설정 하시오
#  marker를 클릭 했을때 시장 이름이 나타나도록 설정

# %%
# -*- coding: utf-8 -*-

# 라이브러리 불러오기
import pandas as pd
import folium

#  데이터프레임 변환
df = pd.read_csv('/content/인천광역시 미추홀구_재래시장_20220822.csv',  encoding = 'CP949')  # 수준원점 기준

print(df)

# 지도 만들기
# 7호관뒤 수준 원점 중심 37.449405, 126.657369
smap = folium.Map(location=[37.449405, 126.657369], tiles='Stamen Terrain', zoom_start=14)


# 재래시장 위치정보를 Marker로 표시
for name, lat, lng in zip(df.시장명, df.위도, df.경도):
  folium.Marker([lat, lng], popup=name).add_to(smap)
smap
# Out:
#     연번       시장명                             도로명주소          전화번호         위도  \
# 0    1      신기시장       인천광역시  미추홀구 미추홀대로 547 (주안동)  032-865-5424  37.446216
# 1    2      용현시장       인천광역시  미추홀구 용삼길 65-27 (용현동)  032-886-9318  37.458238
# 2    3     석바위시장   인천광역시  미추홀구 경인로485번길 17-1 (주안동)  032-426-6877  37.460147
# 3    4    토지금고시장           인천광역시  미추홀구 낙섬중로 38번길 5  032-887-8985  37.451550
# 4    5      용남시장  인천광역시 미추홀구 인주대로 266번길 17-1 (용현동)  032-868-2349  37.451898
# 5    6      제일시장       인천광역시 미추홀구 제일로 37번길 5 (도화동)           NaN  37.459199
# 6    7    도화종합시장          인천광역시  미추홀구 석정로 279번길 7   032-864-2672  37.468679
# 7    8  인천남부종합시장            인천광역시  미추홀구 인하로 274-30  032-864-1331  37.447375
# 8    9      용일시장        인천광역시  미추홀구 인주대로 184 (용현동)           NaN  37.455320
# 9   10     제물포시장           인천광역시 미추홀구 수봉로 33 (숭의동)           NaN  37.463178
# 10  11    통일종합시장     인천광역시 미추홀구 인하로 267번길 14 (주안동)           NaN  37.449169
# 11  12    숭의평화시장         인천광역시 미추홀구 참외전로 309 (숭의동)  032-884-6434  37.466445
# 12  13      공단시장          인천광역시 미추홀구 석정로 399 (주안동)           NaN  37.467242
# 13  14    주안자유시장     인천광역시 미추홀구 경인로 326번길 71 (주안동)           NaN  37.455512
# 14  15      학익시장         인천광역시 미추홀구 한나루로 400 (학익동)  032-873-7378  37.443515
#
#             경도
# 0   126.678645
# 1   126.652597
# 2   126.692735
# 3   126.637802
# 4   126.665849
# 5   126.674352
# 6   126.666506
# 7   126.678396
# 8   126.657223
# 9   126.656771
# 10  126.678418
# 11  126.648563
# 12  126.680137
# 13  126.676048
# 14  126.664965
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_519b943d6fa9bbb1b7cf7a00263fe59b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_519b943d6fa9bbb1b7cf7a00263fe59b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_519b943d6fa9bbb1b7cf7a00263fe59b = L.map(
#                 &quot;map_519b943d6fa9bbb1b7cf7a00263fe59b&quot;,
#                 {
#                     center: [37.449405, 126.657369],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf474f78e1c66d403ae3e78d30697058 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_519b943d6fa9bbb1b7cf7a00263fe59b);
#
#
#             var marker_cdfa4230566b13cb60e4bd5374bbac17 = L.marker(
#                 [37.44621554, 126.6786452],
#                 {}
#             ).addTo(map_519b943d6fa9bbb1b7cf7a00263fe59b);
#
#
#         var popup_93977c6222b9e2649d8e372352b77637 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c102ea14b4ce00ef68aebfc514031bdc = $(`&lt;div id=&quot;html_c102ea14b4ce00ef68aebfc514031bdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신기시장&lt;/div&gt;`)[0];
#             popup_93977c6222b9e2649d8e372352b77637.setContent(html_c102ea14b4ce00ef68aebfc514031bdc);
#
#
#         marker_cdfa4230566b13cb60e4bd5374bbac17.bindPopup(popup_93977c6222b9e2649d8e372352b77637)
#         ;
#
#
#
#
#             var marker_bf200d819492ff235d4e6522e20ce916 = L.marker(
#                 [37.45823789, 126.6525966],
#                 {}
#             ).addTo(map_519b943d6fa9bbb1b7cf7a00263fe59b);
#
#
#         var popup_6a8cbada44ac90b7b2df2c5adcd66669 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4fc483c4be44360d3b1b144bb406ccec = $(`&lt;div id=&quot;html_4fc483c4be44360d3b1b144bb406ccec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;용현시장&lt;/div&gt;`)[0];
#             popup_6a8cbada44ac90b7b2df2c5adcd66669.setContent(html_4fc483c4be44360d3b1b144bb406ccec);
#
#
#         marker_bf200d819492ff235d4e6522e20ce916.bindPopup(popup_6a8cbada44ac90b7b2df2c5adcd66669)
#         ;
#
#
#
#
#             var marker_b6d055984f4a5d73bed9dd25819a9af1 = L.marker(
#                 [37.46014695, 126.6927355],
#                 {}
#             ).addTo(map_519b943d6fa9bbb1b7cf7a00263fe59b);
#
#
#         var popup_1da124df95b84442c2219b59fdaad6b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d638fbe648873c169d5e06689e5e964c = $(`&lt;div id=&quot;html_d638fbe648873c169d5e06689e5e964c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;석바위시장&lt;/div&gt;`)[0];
#             popup_1da124df95b84442c2219b59fdaad6b0.setContent(html_d638fbe648873c169d5e06689e5e964c);
#
#
#         marker_b6d055984f4a5d73bed9dd25819a9af1.bindPopup(popup_1da124df95b84442c2219b59fdaad6b0)
#         ;
#
#
#
#
#             var marker_0a9c21cf581cc644ee91e34cb385bfb6 = L.marker(
#                 [37.45154989, 126.6378022],
#                 {}
#             ).addTo(map_519b943d6fa9bbb1b7cf7a00263fe59b);
#
#
#         var popup_d2b90f925071423a00b5f1ae36daf3b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_3b4bbb651c9f268eef6f583570147e6d = $(`&lt;div id=&quot;html_3b4bbb651c9f268eef6f583570147e6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;토지금고시장&lt;/div&gt;`)[0];
#             popup_d2b90f925071423a00b5f1ae36daf3b0.setContent(html_3b4bbb651c9f268eef6f583570147e6d);
#
#
#         marker_0a9c21cf581cc644ee91e34cb385bfb6.bindPopup(popup_d2b90f925071423a00b5f1ae36daf3b0)
#         ;
#
#
#
#
#             var marker_0cc2c69d5f8351e8eb79a6ef2eb30f2f = L.marker(
#                 [37.45189805, 126.6658494],
#                 {}
#             ).addTo(map_519b943d6fa9bbb1b7cf7a00263fe59b);
#
#
#         var popup_d966b424764bed94ea9ccc9219bf19b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4e5f18f3fde3e5f6e5a78729336619e5 = $(`&lt;div id=&quot;html_4e5f18f3fde3e5f6e5a78729336619e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;용남시장&lt;/div&gt;`)[0];
#             popup_d966b424764bed94ea9ccc9219bf19b0.setContent(html_4e5f18f3fde3e5f6e5a78729336619e5);
#
#
#         marker_0cc2c69d5f8351e8eb79a6ef2eb30f2f.bindPopup(popup_d966b424764bed94ea9ccc9219bf19b0)
#         ;
#
#
#
#
#             var marker_99ef2f6138c880225ee8942fd2da9cf9 = L.marker(
#                 [37.45919923, 126.6743522],
#                 {}
#             ).addTo(map_519b943d6fa9bbb1b7cf7a00263fe59b);
#
#
#         v

# %% [markdown]
# 과제2) 서울특별시 성북구_약국list.csv 화일에 포함되어 있는
# 약국들의 위치를 circlemarker로 표시 하시오.
#  지도의 중심 위치는 성북 구청으로 설정 하시오
#  circlemarker를 클릭 했을때 약국 이름이 나타나도록 설정

# %%
# -*- coding: utf-8 -*-

# 라이브러리 불러오기
import pandas as pd
import folium

#  리스트를 데이터프레임 변환
df = pd.read_csv('/content/서울특별시 성북구_약국list.csv',  encoding = 'CP949')

# 지도 만들기
# 성북 구청 37.589375 , 127.016741
smap = folium.Map(location=[37.589375 , 127.016741], tiles='Stamen Terrain', zoom_start=14)

for name, lat, lng in zip(df.약국명, df.위도, df.경도):
  folium.CircleMarker([lat, lng],radius=10,color='brown', fill=True,fill_color='coral',
      fill_opacity=0.7,popup=name).add_to(smap)

smap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fd41352331c31c89d6cceddeaa81b7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fd41352331c31c89d6cceddeaa81b7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fd41352331c31c89d6cceddeaa81b7f = L.map(
#                 &quot;map_5fd41352331c31c89d6cceddeaa81b7f&quot;,
#                 {
#                     center: [37.589375, 127.016741],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_670d4ad2de0d55b3252415bf9da1d9b2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fd41352331c31c89d6cceddeaa81b7f);
#
#
#             var circle_marker_9534b5ba2849e38650f3c46f80f8d3ae = L.circleMarker(
#                 [37.60894036, 127.029052],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd41352331c31c89d6cceddeaa81b7f);
#
#
#         var popup_bcdbda1c874ecac741c1832cfc1190a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0797c3095451f513cd8e7799bf808429 = $(`&lt;div id=&quot;html_0797c3095451f513cd8e7799bf808429&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;호수온누리약국&lt;/div&gt;`)[0];
#             popup_bcdbda1c874ecac741c1832cfc1190a5.setContent(html_0797c3095451f513cd8e7799bf808429);
#
#
#         circle_marker_9534b5ba2849e38650f3c46f80f8d3ae.bindPopup(popup_bcdbda1c874ecac741c1832cfc1190a5)
#         ;
#
#
#
#
#             var circle_marker_66376b83702e64a625e291823063aba2 = L.circleMarker(
#                 [37.61040424, 127.0569046],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd41352331c31c89d6cceddeaa81b7f);
#
#
#         var popup_a94982205690d582e253e92a2abd0184 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5434418778b1b410f28ab1654ef34e9a = $(`&lt;div id=&quot;html_5434418778b1b410f28ab1654ef34e9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;돌곶이온누리약국&lt;/div&gt;`)[0];
#             popup_a94982205690d582e253e92a2abd0184.setContent(html_5434418778b1b410f28ab1654ef34e9a);
#
#
#         circle_marker_66376b83702e64a625e291823063aba2.bindPopup(popup_a94982205690d582e253e92a2abd0184)
#         ;
#
#
#
#
#             var circle_marker_65b3961029a945de1081f347b97598be = L.circleMarker(
#                 [37.60101417, 127.0331664],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;coral&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd41352331c31c89d6cceddeaa81b7f);
#
#
#         var popup_1b0235556b93c497537e9a2272a9e550 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6f0e9297305454b3f8899530cc896e3b = $(`&lt;div id=&quot;html_6f0e9297305454b3f8899530cc896e3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;홀리데이약국&lt;/div&gt;`)[0];
#             popup_1b0235556b93c497537e9a2272a9e550.setContent(html_6f0e9297305454b3f8899530cc896e3b);
#
#
#         circle_marker_65b3961029a945de1081f347b97598be.bindPopup(popup_1b0235556b93c497537e9a2272a9e550)
#         ;
#
#
#
#
#             var circle_marker_af012501fdc664e1ef3e9424a1b27696 = L.circleMarker(
#                 [37.59373053, 127.0159792],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;brown&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;:

# %% [markdown]
# 과제3. 서울시의 구별 인구수 ( 총생활인구수    )를 단계 구분도(choropleth)를 이용하여 표시 하시오.
# 구분이 잘 되도록 threshold_scale을 적절히 설정.
#
# chprpleth 함수의 parameter 중 key_on은
# 'feature.properties.name' 으로 설정.

# %%
import pandas as pd

import folium

df=pd.read_csv('/content/서울구별인구.csv')
#df.columns = df.columns.map(str)


print(df.head())
import requests
import json
import re

# 서울 행정구역 json raw파일(githubcontent)https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json
s_geo='https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

s_map = folium.Map(location=[37.559984,126.9753071],  # 숭례문 위도, 경도
                   tiles='Stamen Terrain', zoom_start=11)


s_map

# Choropleth 클래스로 단계구분도 표시하기
folium.Choropleth(geo_data=s_geo, data = df,columns = ['시군구명','인구수'],
fill_color='YlOrRd', fill_opacity=0.7, line_opacity=0.3,
threshold_scale=[200, 300, 400, 500, 600, 700, 800],
key_on='feature.properties.name').add_to(s_map)

s_map
# Out:
#       기준일ID  시군구코드 시군구명  인구수       총생활인구수     내국인생활인구수  장기체류외국인인구수  \
# 0  20221105  11110  종로구  299  299711.6286  269531.1395  17687.8690
# 1  20221105  11140   중구  268  268413.4217  215788.9233  17730.5069
# 2  20221105  11170  용산구  296  296264.2489  272201.6028  16908.7793
# 3  20221105  11200  성동구  346  346978.2575  327533.3117  16690.4480
# 4  20221105  11215  광진구  385  385909.7098  360337.6724  22446.5917
#
#    단기체류외국인인구수       일최대인구수       일최소인구수  주간인구수(09~18)  야간인구수(19~08)  \
# 0  12492.6201  420491.3983  229367.8299   368107.3021   250857.5762
# 1  34893.9915  344814.2942  209744.7507   321168.3035   230731.3633
# 2   7153.8669  326482.8175  274015.5366   313517.5125   283940.4892
# 3   2754.4978  365868.2481  332101.4179   354076.2544   341908.2597
# 4   3125.4457  395090.8185  376791.2038   379787.5538   390282.6784
#
#       일최대이동인구수    서울외유입인구수  동일자치구행정동간이동인구수    자치구간이동인구수
# 0  253376.9511  88685.1264      28580.2546  136111.5701
# 1  204500.4984  63200.6201      26755.0629  114544.8154
# 2  166080.4940  51253.1096      41897.0890   72930.2954
# 3  179253.0773  41237.6455      54451.9150   83563.5168
# 4  168555.0409  38592.6934      70825.0044   59137.3431
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85eeea051307c2371f83d7b06c07d32f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85eeea051307c2371f83d7b06c07d32f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85eeea051307c2371f83d7b06c07d32f = L.map(
#                 &quot;map_85eeea051307c2371f83d7b06c07d32f&quot;,
#                 {
#                     center: [37.559984, 126.9753071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_558145ed583a8a407816f28fb9ba5ba3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_85eeea051307c2371f83d7b06c07d32f);
#
#
#             var choropleth_8ecb7e5b4127ee7ede05d4c5964011d7 = L.featureGroup(
#                 {}
#             ).addTo(map_85eeea051307c2371f83d7b06c07d32f);
#
#
#         function geo_json_d8f3e1f4daf3e2ab345d1519e689716d_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11220&quot;: case &quot;11160&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;11240&quot;: case &quot;11230&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;11210&quot;: case &quot;11190&quot;: case &quot;11170&quot;: case &quot;11140&quot;: case &quot;11120&quot;: case &quot;11110&quot;: case &quot;11080&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;11180&quot;: case &quot;11100&quot;: case &quot;11090&quot;: case &quot;11030&quot;: case &quot;11020&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d8f3e1f4daf3e2ab345d1519e689716d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d8f3e1f4daf3e2ab345d1519e689716d = L.geoJson(null, {
#                 onEachFeature: geo_json_d8f3e1f4daf3e2ab345d1519e689716d_onEachFeature,
#
#                 style: geo_json_d8f3e1f4daf3e2ab345d1519e689716d_styler,
#         });
#
#         function geo_json_d8f3e1f4daf3e2ab345d1519e689716d_add (data) {
#             geo_json_d8f3e1f4daf3e2ab345d1519e689716d
#                 .addData(data)
#                 .addTo(choropleth_8ecb7e5b4127ee7ede05d4c5964011d7);
#         }
#             geo_json_d8f3e1f4daf3e2ab345d1519e689716d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.5191871
